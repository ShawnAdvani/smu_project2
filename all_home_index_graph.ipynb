# %%
import pandas as pd
import gmaps
gmaps.configure(api_key="AIzaSyB6nP7f6nYa0m-gRi68GCjZFTVlMZq-pqk")

# %%
# Import median sale price PSF data by city and transpose
sale_df = pd.read_csv('new_allhome.csv', encoding = "Latin", index_col='RegionName')
sale_df = sale_df.sort_values('2019-09', ascending = False)

# Drop 'N/A' Columns
sale_df = sale_df.dropna(1)
sale_df.head()
# Out:
#               State   Latitude   Longitude          CountyName  SizeRank  \
# RegionName
# Sagaponack       NY  40.925378  -72.278137      Suffolk County      7239
# Aspen            CO  39.191098 -106.817539       Pitkin County      4391
# Palo Alto        CA  37.441883 -122.143020  Santa Clara County       712
# Del Mar          CA  32.959489 -117.265315    San Diego County      6607
# Beverly Hills    CA  34.073620 -118.400356  Los Angeles County      1568
#
#                    2018-10      2018-11      2018-12      2019-01  \
# RegionName
# Sagaponack     1738.361815  1690.238278  1651.984127  1675.674695
# Aspen          1597.096202  1623.341457  1664.225627  1681.530110
# Palo Alto      1503.666979  1505.460218  1519.176225  1489.542727
# Del Mar        1537.803626  1755.105627  1802.456499  1683.518467
# Beverly Hills  1568.016687  1568.016687  1613.924051  1608.948820
#
#                    2019-02      2019-03      2019-04      2019-05  \
# RegionName
# Sagaponack     1707.188105  1661.111111  1744.964292  1738.361815
# Aspen          1700.907150  1692.047205  1696.721864  1687.060548
# Palo Alto      1530.627871  1534.917460  1569.475505  1590.515276
# Del Mar        1713.541667  1731.892547  1606.280193  1637.013154
# Beverly Hills  1613.911832  1513.132851  1547.864740  1534.062787
#
#                    2019-06      2019-07      2019-08      2019-09
# RegionName
# Sagaponack     1738.361815  1738.361815  1590.909091  1714.300047
# Aspen          1700.354610  1658.333333  1658.333333  1652.432340
# Palo Alto      1633.804019  1581.272085  1563.915134  1642.265385
# Del Mar        1606.280193  1545.710267  1541.756947  1641.598171
# Beverly Hills  1559.375000  1561.176927  1570.740514  1622.989989

# %%
sale_df.columns
# Out:
# Index(['State', 'Latitude', 'Longitude', 'CountyName', 'SizeRank', '2018-10',
#        '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04',
#        '2019-05', '2019-06', '2019-07', '2019-08', '2019-09'],
#       dtype='object')

# %%
latlongdf=sale_df[['State', 'Latitude', 'Longitude', 'CountyName', 'SizeRank',]].reset_index()

# %%
latlongdf['index']=latlongdf.index

# %%
df = latlongdf[['index', 'RegionName','State', 'Latitude', 'Longitude', 'CountyName']]
df
# Out:
#       index        RegionName State   Latitude   Longitude  \
# 0         0        Sagaponack    NY  40.925378  -72.278137
# 1         1             Aspen    CO  39.191098 -106.817539
# 2         2         Palo Alto    CA  37.441883 -122.143020
# 3         3           Del Mar    CA  32.959489 -117.265315
# 4         4     Beverly Hills    CA  34.073620 -118.400356
# 5         5     Fisher Island    FL  25.760933  -80.140046
# 6         6         Telluride    CO  37.937494 -107.812285
# 7         7        Menlo Park    CA  37.452960 -122.181725
# 8         8      Laguna Beach    CA  33.542719 -117.785357
# 9         9            Malibu    CA  34.025922 -118.779757
# 10       10   Manhattan Beach    CA  33.884736 -118.410909
# 11       11         Montecito    CA  34.436663 -119.632075
# 12       12      Saint Helena    CA  38.505243 -122.470387
# 13       13        Burlingame    CA  37.577870 -122.348090
# 14       14      Santa Monica    CA  34.019454 -118.491191
# 15       15     San Francisco    CA  37.774929 -122.419415
# 16       16         Cupertino    CA  37.322998 -122.032182
# 17       17         Nantucket    MA  41.283470  -70.099451
# 18       18              Vail    CO  39.640264 -106.374196
# 19       19     Hermosa Beach    CA  33.862237 -118.399519
# 20       20           Tiburon    CA  37.873538 -122.456639
# 21       21        San Carlos    CA  37.507159 -122.260522
# 22       22     Mountain View    CA  37.386052 -122.083851
# 23       23          Saratoga    CA  37.263832 -122.023015
# 24       24          Coronado    CA  32.685885 -117.183089
# 25       25           Belmont    CA  37.520215 -122.275801
# 26       26     Newport Beach    CA  33.618883 -117.929849
# 27       27           Kilauea    HI  22.211944 -159.412222
# 28       28      Stone Harbor    NJ  39.046407  -74.764361
# 29       29      Redwood City    CA  37.485215 -122.236355
# ...     ...               ...   ...        ...         ...
# 7231   7231           Hornell    NY  42.327848  -77.661102
# 7232   7232       Laurel Lake    NJ  39.327330  -75.031400
# 7233   7233             Sayre    PA  41.978963  -76.515499
# 7234   7234          Midfield    AL  33.461408  -86.908681
# 7235   7235             Flint    MI  43.012527  -83.687456
# 7236   7236           Towanda    PA  41.767575  -76.442719
# 7237   7237       Monongahela    PA  40.203127  -79.926160
# 7238   7238      Gloversville    NY  43.052851  -74.343747
# 7239   7239            Warren    OH  41.237557  -80.818417
# 7240   7240              Gary    IN  41.602040  -87.337152
# 7241   7241         Ballinger    TX  31.738206  -99.947308
# 7242   7242              York    PA  39.962598  -76.727745
# 7243   7243           Tarrant    AL  33.586822  -86.771802
# 7244   7244         Salamanca    NY  42.157841  -78.715031
# 7245   7245  Muskegon Heights    MI  43.201126  -86.238946
# 7246   7246           Parsons    KS  37.340338  -95.261084
# 7247   7247          Plymouth    PA  41.240360  -75.944643
# 7248   7248           Chester    PA  39.849557  -75.355746
# 7249   7249            Harvey    IL  41.610034  -87.646713
# 7250   7250       Coffeyville    KS  37.037301  -95.616366
# 7251   7251          Steelton    PA  40.235368  -76.841361
# 7252   7252          Berkeley    MO  38.754495  -90.331226
# 7253   7253        New Castle    PA  41.003672  -80.347009
# 7254   7254        Pottsville    PA  40.685646  -76.195499
# 7255   7255          Oil City    PA  41.433948  -79.706441
# 7256   7256        Youngstown    OH  41.099780  -80.649519
# 7257   7257           Cahokia    IL  38.570885  -90.190111
# 7258   7258        McKeesport    PA  40.347067  -79.864123
# 7259   7259          Jennings    MO  38.719217  -90.260390
# 7260   7260       Monroeville    AL  31.527940  -87.324708
#
#                 CountyName
# 0           Suffolk County
# 1            Pitkin County
# 2       Santa Clara County
# 3         San Diego County
# 4       Los Angeles County
# 5        Miami-Dade County
# 6        San Miguel County
# 7         San Mateo County
# 8            Orange County
# 9       Los Angeles County
# 10      Los Angeles County
# 11    Santa Barbara County
# 12             Napa County
# 13        San Mateo County
# 14      Los Angeles County
# 15    San Francisco County
# 16      Santa Clara County
# 17        Nantucket County
# 18            Eagle County
# 19      Los Angeles County
# 20            Marin County
# 21        San Mateo County
# 22      Santa Clara County
# 23      Santa Clara County
# 24        San Diego County
# 25        San Mateo County
# 26           Orange County
# 27            Kauai County
# 28         Cape May County
# 29        San Mateo County
# ...                    ...
# 7231        Steuben County
# 7232     Cumberland County
# 7233       Bradford County
# 7234      Jefferson County
# 7235        Genesee County
# 7236       Bradford County
# 7237     Washington County
# 7238         Fulton County
# 7239       Trumbull County
# 7240           Lake County
# 7241        Runnels County
# 7242           York County
# 7243      Jefferson County
# 7244    Cattaraugus County
# 7245       Muskegon County
# 7246        Labette County
# 7247        Luzerne County
# 7248       Delaware County
# 7249           Cook County
# 7250     Montgomery County
# 7251        Dauphin County
# 7252    Saint Louis County
# 7253       Lawrence County
# 7254     Schuylkill County
# 7255        Venango County
# 7256       Mahoning County
# 7257    Saint Clair County
# 7258      Allegheny County
# 7259    Saint Louis County
# 7260         Monroe County
#
# [7261 rows x 6 columns]

# %%
from sqlalchemy import create_engine
rds_connection_string = "postgres:Graduate1@localhost:5432/zillow_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
df.to_sql(name='CityLatLong', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UniqueViolation: duplicate key value violates unique constraint "pk_CityLatLong"
# DETAIL:  Key (index)=(0) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-8-1e8869f92c41> in <module>
# ----> 1 df.to_sql(name='CityLatLong', con=engine, if_exists='append', index=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "pk_CityLatLong"
# DETAIL:  Key (index)=(0) already exists.
#
# [SQL: INSERT INTO "CityLatLong" (index, "RegionName", "State", "Latitude", "Longitude", "CountyName") VALUES (%(index)s, %(RegionName)s, %(State)s, %(Latitude)s, %(Longitude)s, %(CountyName)s)]
# [parameters: ({'index': 0, 'RegionName': 'Sagaponack', 'State': 'NY', 'Latitude': 40.925377600000004, 'Longitude': -72.2781375, 'CountyName': 'Suffolk County'}, {'index': 1, 'RegionName': 'Aspen', 'State': 'CO', 'Latitude': 39.19109829999999, 'Longitude': -106.81753870000001, 'CountyName': 'Pitkin County'}, {'index': 2, 'RegionName': 'Palo Alto', 'State': 'CA', 'Latitude': 37.441883399999995, 'Longitude': -122.14301950000001, 'CountyName': 'Santa Clara County'}, {'index': 3, 'RegionName': 'Del Mar', 'State': 'CA', 'Latitude': 32.9594891, 'Longitude': -117.2653146, 'CountyName': 'San Diego County'}, {'index': 4, 'RegionName': 'Beverly Hills', 'State': 'CA', 'Latitude': 34.073620399999996, 'Longitude': -118.40035630000001, 'CountyName': 'Los Angeles County'}, {'index': 5, 'RegionName': 'Fisher Island', 'State': 'FL', 'Latitude': 25.7609329, 'Longitude': -80.1400459, 'CountyName': 'Miami-Dade County'}, {'index': 6, 'RegionName': 'Telluride', 'State': 'CO', 'Latitude': 37.9374939, 'Longitude': -107.81228519999999, 'CountyName': 'San Miguel County'}, {'index': 7, 'RegionName': 'Menlo Park', 'State': 'CA', 'Latitude': 37.4529598, 'Longitude': -122.1817252, 'CountyName': 'San Mateo County'}  ... displaying 10 of 7261 total bound parameter sets ...  {'index': 7259, 'RegionName': 'Jennings', 'State': 'MO', 'Latitude': 38.7192175, 'Longitude': -90.2603903, 'CountyName': 'Saint Louis County'}, {'index': 7260, 'RegionName': 'Monroeville', 'State': 'AL', 'Latitude': 31.527939899999996, 'Longitude': -87.3247077, 'CountyName': 'Monroe County'})]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
# Create a Total Score Heatmap layer
fig = gmaps.figure()
locations = sale_df[['Latitude', 'Longitude']]
weight=sale_df['2019-09']
heat_layer = gmaps.heatmap_layer(locations, weights=weight, 
                                 dissipating=False, max_intensity=100, point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
list(sale_df['2019-09'])

# %%
sale_df.Latitude.size

# %%
sale_df.Latitude.size

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (0.9.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from gmaps) (4.3.2)
# Requirement already satisfied: ipython>=5.3.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from gmaps) (7.6.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from gmaps) (7.5.0)
# Requirement already satisfied: geojson>=2.0.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: six in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from gmaps) (1.12.0)
# Requirement already satisfied: ipython-genutils in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: decorator in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.0->gmaps) (4.4.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (41.0.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (2.0.9)
# Requirement already satisfied: pygments in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (2.4.2)
# Requirement already satisfied: pickleshare in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.13.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (4.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.1)
# Requirement already satisfied: wcwidth in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.7)
# Requirement already satisfied: parso>=0.3.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->gmaps) (0.6.0)
# Requirement already satisfied: jupyter-core in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.5.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.0.1)
# Requirement already satisfied: notebook>=4.4.1 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.0)
# Requirement already satisfied: jupyter-client in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.3.1)
# Requirement already satisfied: tornado>=4.2 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.14.11)
# Requirement already satisfied: terminado>=0.8.1 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.2)
# Requirement already satisfied: jinja2 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.10.1)
# Requirement already satisfied: Send2Trash in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: nbconvert in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.5.0)
# Requirement already satisfied: prometheus-client in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: pyzmq>=17 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (18.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: bleach in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: testpath in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.2)
# Requirement already satisfied: defusedxml in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: mistune>=0.8.1 in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: webencodings in /Users/aaronmorgan/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
